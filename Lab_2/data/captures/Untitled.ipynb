# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
npz_upper = np.load('test_upper.npz', allow_pickle=True)
npz_lower = np.load('test_lower.npz', allow_pickle=True)

# %%
real_upper = npz_upper['real']
image_upper= npz_upper['image']

real_lower = npz_lower['real']
image_lower =  npz_lower['image']

# %%
plt.figure()
plt.plot(real_upper[7,:2000])
plt.plot(image_upper[7,:2000])

# %%
power_upper = np.mean(np.abs(np.fft.fft(real_upper+1.0j*image_upper, axis=1))**2, axis=0)
power_lower = np.mean(np.abs(np.fft.fft(real_lower+1.0j*image_lower, axis=1))**2, axis=0)

# %%
times = np.linspace(0, 16000/62.5e6, 16000)
freqs = np.fft.fftfreq(len(times), np.median(np.diff(times)))

# %%
# %matplotlib notebook

# %%
plt.figure()
plt.plot(np.fft.fftshift(freqs/1e6), np.fft.fftshift(power_upper))
plt.plot(np.fft.fftshift(freqs/1e6), np.fft.fftshift(power_lower))

plt.xlim(-3,3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-3, 3)

# %%
plt.figure()
plt.plot(np.fft.fftshift(freqs/1e6), np.fft.fftshift(power_upper/power_lower))

plt.xlim(-3,3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-3, 3)

# %%
v = 3e5/1420.4e6*np.linspace(-.5e6, .5e6, 16000)

# %%
plt.figure()
plt.plot(v, np.fft.fftshift(power_upper/power_lower))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
real, image, t0, tf, coord_0, coord_f = [npz

# %%
power_on = np.load('power_on.npz')
power_off = np.load('power_off.npz')

power_avg_on = power_on['avg']
power_median_on=power_on['median']
power_single_on = power_on['single']

power_avg_off = power_off['avg']
power_median_off=power_off['median']
power_single_off = power_off['single']

# %%
50000/4
# Out:
# 12500.0

# %%
power_median_on = np.median(power_median_on.reshape(25000, 2), axis=1)
power_median_off = np.median(power_median_off.reshape(25000, 2), axis=1)

# %%
times = np.linspace(0, 25000/62.5e6, 25000)
freqs = np.fft.fftfreq(len(times), np.median(np.diff(times)))

# %%
s_line = power_median_off/power_median_on*104

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, sharex=True, gridspec_kw={'hspace':0})
ax1.semilogy(np.fft.fftshift(freqs/1e6), np.fft.fftshift(power_median_on))
ax1.semilogy(np.fft.fftshift(freqs/1e6), np.fft.fftshift(power_median_off))

ax2.plot(np.fft.fftshift(freqs/1e6), np.fft.fftshift(s_line))

ax2.set_xlim(-2, 2)
ax2.set_ylim(70,140)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (70, 140)

# %%
rf = freqs+1230e6+190e6 -1e6

# %%
plt.figure()
plt.plot(np.fft.fftshift(rf/1e6), np.fft.fftshift(s_line))
plt.xlim(1416, 1424)
plt.ylim(75, 130)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (75, 130)

# %%
v = 3e5/1420.2e6*(rf-1420.2e6)

# %%
plt.figure()
plt.plot(np.fft.fftshift(v), np.fft.fftshift(s_line))
plt.ylim(75, 150)
# plt.xlim(-100, 100)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (75, 150)

# %%
power_on = np.load('power_on_16000.npz')
power_off = np.load('power_off_16000.npz')

power_avg_on = power_on['avg']
power_median_on=power_on['median']
power_single_on = power_on['single']

power_avg_off = power_off['avg']
power_median_off=power_off['median']
power_single_off = power_off['single']

power_median_on = np.mean(power_median_on.reshape(8000,2), axis=1)
power_median_off = np.mean(power_median_off.reshape(8000,2), axis=1)

times = np.linspace(0, 8000/62.5e6, 8000)
freqs = np.fft.fftfreq(len(times), np.median(np.diff(times)))


s_line = power_median_on/power_median_off

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, sharex=True, gridspec_kw={'hspace':0})
ax1.semilogy(np.fft.fftshift(freqs/1e6), np.fft.fftshift(power_median_on))
ax1.semilogy(np.fft.fftshift(freqs/1e6), np.fft.fftshift(power_median_off))

ax2.semilogy(np.fft.fftshift(freqs/1e6), np.fft.fftshift(s_line))

ax2.set_xlim(-1, 1.5)
# ax2.set_ylim(-1,1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-1, 1.5)

# %%
rf = freqs +190e6+1230e6

# %%
plt.figure()
plt.semilogy(rf/1e6, s_line)
plt.xlim(1410, 1430)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (1410, 1430)

# %%
v = 3e5/1420.2e6*np.linspace(-.5e6, .5e6, 8000)

# %%
plt.figure()
plt.plot(v, np.fft.fftshift(s_line))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from ugradio import timing

# %%
timing.lst()*12/np.pi
# Out:
# 23.929394229682977
